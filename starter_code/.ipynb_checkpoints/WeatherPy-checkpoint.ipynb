# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup #
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import pprint


import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data_cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# cities
# Out:
# 641

# %%
# cities

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# creating empty lists to fill API data.
city_name=[]
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# %%
def get_weather(city, api_key):
    url = "http://api.openweathermap.org/data/2.5/weather"
    payload = {
        "appid": api_key,
        "q":city
    }
    r = requests.get(url,params=payload)
    if r.status_code == 200:
        return r.json()
    else: 
        return None

# %%
# getting data in json format.
all_cities_json = []
for city in cities:
    result = get_weather(city,api_key)
    if result: 
        all_cities_json.append(result)
# all_cities_json

# %%
# showing first 2 items of all the data in json format
all_cities_json[0:2]
# Out:
# [{'coord': {'lon': 150.17, 'lat': 59.7},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 267.64,
#    'feels_like': 255.33,
#    'temp_min': 267.64,
#    'temp_max': 267.64,
#    'pressure': 1016,
#    'humidity': 76,
#    'sea_level': 1016,
#    'grnd_level': 1016},
#   'wind': {'speed': 13.33, 'deg': 81},
#   'clouds': {'all': 99},
#   'dt': 1578153185,
#   'sys': {'country': 'RU', 'sunrise': 1578178625, 'sunset': 1578201062},
#   'timezone': 39600,
#   'id': 2127060,
#   'name': 'Arman',
#   'cod': 200},
#  {'coord': {'lon': 18.42, 'lat': -33.93},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 296.72,
#    'feels_like': 294.12,
#    'temp_min': 293.71,
#    'temp_max': 299.26,
#    'pressure': 1010,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 6.2, 'deg': 170},
#   'clouds': {'all': 0},
#   'dt': 1578152606,
#   'sys': {'type': 1,
#    'id': 1899,
#    'country': 'ZA',
#    'sunrise': 1578109236,
#    'sunset': 1578160858},
#   'timezone': 7200,
#   'id': 3369157,
#   'name': 'Cape Town',
#   'cod': 200}]

# %%
print("Begining Data Retrieval")
print('-'*29)
count = 1  # counter to count the number of call for APIs. 
sets = 1  # counter to count the number of call sets.

for e in range(len(all_cities_json)):
    try:
        print(f"Procssing Record {count} of {sets} | {cities[e]}")
        city_name.append(all_cities_json[e]['name'])
        country.append(all_cities_json[e]['sys']['country'])
        humidity.append(all_cities_json[e]['main']['humidity'])
        date.append(all_cities_json[e]['dt'])
        cloudiness.append(all_cities_json[e]['clouds']['all'])
        lat.append(all_cities_json[e]['coord']['lat'])
        lng.append(all_cities_json[e]['coord']['lon'])
        max_temp.append(all_cities_json[e]['main']['temp_max'])
        wind_speed.append(all_cities_json[e]['wind']['speed'])
        
        count += 1
            
    except:
        print("City not found. Skipping...")
        err += 1
    if count == 51:
        
        count =1 
        sets +=1
    
print('-'*35)
print("Data Retrieval Complete")
print('-'*35)
# Out:
# Begining Data Retrieval
# -----------------------------
# Procssing Record 1 of 1 | arman
# Procssing Record 2 of 1 | cape town
# Procssing Record 3 of 1 | vaitupu
# Procssing Record 4 of 1 | banda aceh
# Procssing Record 5 of 1 | clyde river
# Procssing Record 6 of 1 | kidal
# Procssing Record 7 of 1 | saint george
# Procssing Record 8 of 1 | bluff
# Procssing Record 9 of 1 | vaini
# Procssing Record 10 of 1 | ilo
# Procssing Record 11 of 1 | rikitea
# Procssing Record 12 of 1 | khatanga
# Procssing Record 13 of 1 | illoqqortoormiut
# Procssing Record 14 of 1 | port alfred
# Procssing Record 15 of 1 | avarua
# Procssing Record 16 of 1 | ribeira grande
# Procssing Record 17 of 1 | manokwari
# Procssing Record 18 of 1 | baruun-urt
# Procssing Record 19 of 1 | hendijan
# Procssing Record 20 of 1 | port macquarie
# Procssing Record 21 of 1 | dakar
# Procssing Record 22 of 1 | arraial do cabo
# Procssing Record 23 of 1 | praia da vitoria
# Procssing Record 24 of 1 | gat
# Procssing Record 25 of 1 | arlit
# Procssing Record 26 of 1 | bredasdorp
# Procssing Record 27 of 1 | kapaa
# Procssing Record 28 of 1 | nouadhibou
# Procssing Record 29 of 1 | hobart
# Procssing Record 30 of 1 | tuktoyaktuk
# Procssing Record 31 of 1 | seryshevo
# Procssing Record 32 of 1 | katsuura
# Procssing Record 33 of 1 | sovetskaya gavan
# Procssing Record 34 of 1 | holme
# Procssing Record 35 of 1 | ushuaia
# Procssing Record 36 of 1 | road town
# Procssing Record 37 of 1 | longyearbyen
# Procssing Record 38 of 1 | cidreira
# Procssing Record 39 of 1 | mar del plata
# Procssing Record 40 of 1 | aguas verdes
# Procssing Record 41 of 1 | busselton
# Procssing Record 42 of 1 | mont-saint-guibert
# Procssing Record 43 of 1 | hokitika
# Procssing Record 44 of 1 | albany
# Procssing Record 45 of 1 | ust-kuyga
# Procssing Record 46 of 1 | taolanaro
# Procssing Record 47 of 1 | port lincoln
# Procssing Record 48 of 1 | zainsk
# Procssing Record 49 of 1 | tiksi
# Procssing Record 50 of 1 | moose factory
# Procssing Record 1 of 2 | sorland
# Procssing Record 2 of 2 | quatre cocos
# Procssing Record 3 of 2 | hermanus
# Procssing Record 4 of 2 | solsvik
# Procssing Record 5 of 2 | novikovo
# Procssing Record 6 of 2 | provideniya
# Procssing Record 7 of 2 | maroantsetra
# Procssing Record 8 of 2 | east london
# Procssing Record 9 of 2 | novyy urgal
# Procssing Record 10 of 2 | riyadh
# Procssing Record 11 of 2 | vardo
# Procssing Record 12 of 2 | eirunepe
# Procssing Record 13 of 2 | kincardine
# Procssing Record 14 of 2 | puerto ayora
# Procssing Record 15 of 2 | ilulissat
# Procssing Record 16 of 2 | sosva
# Procssing Record 17 of 2 | cortez
# Procssing Record 18 of 2 | iqaluit
# Procssing Record 19 of 2 | mataura
# Procssing Record 20 of 2 | kamenskoye
# Procssing Record 21 of 2 | saint anthony
# Procssing Record 22 of 2 | tuatapere
# Procssing Record 23 of 2 | yellowknife
# Procssing Record 24 of 2 | jamestown
# Procssing Record 25 of 2 | kalmunai
# Procssing Record 26 of 2 | barrow
# Procssing Record 27 of 2 | tromso
# Procssing Record 28 of 2 | vila franca do campo
# Procssing Record 29 of 2 | qaanaaq
# Procssing Record 30 of 2 | pandan
# Procssing Record 31 of 2 | mikkeli
# Procssing Record 32 of 2 | vao
# Procssing Record 33 of 2 | haines junction
# Procssing Record 34 of 2 | castro
# Procssing Record 35 of 2 | guerrero negro
# Procssing Record 36 of 2 | puntarenas
# Procssing Record 37 of 2 | mocuba
# Procssing Record 38 of 2 | rungata
# Procssing Record 39 of 2 | general roca
# Procssing Record 40 of 2 | jutai
# Procssing Record 41 of 2 | zachagansk
# Procssing Record 42 of 2 | yar-sale
# Procssing Record 43 of 2 | esperance
# Procssing Record 44 of 2 | punta arenas
# Procssing Record 45 of 2 | carnarvon
# Procssing Record 46 of 2 | bud
# Procssing Record 47 of 2 | yomitan
# Procssing Record 48 of 2 | kholodnyy
# Procssing Record 49 of 2 | beringovskiy
# Procssing Record 50 of 2 | saleaula
# Procssing Record 1 of 3 | vestmannaeyjar
# Procssing Record 2 of 3 | lufilufi
# Procssing Record 3 of 3 | mangai
# Procssing Record 4 of 3 | thompson
# Procssing Record 5 of 3 | belushya guba
# Procssing Record 6 of 3 | nizhneyansk
# Procssing Record 7 of 3 | sao filipe
# Procssing Record 8 of 3 | lazaro cardenas
# Procssing Record 9 of 3 | sumbawa
# Procssing Record 10 of 3 | little current
# Procssing Record 11 of 3 | ndjole
# Procssing Record 12 of 3 | birao
# Procssing Record 13 of 3 | uttaradit
# Procssing Record 14 of 3 | mitsamiouli
# Procssing Record 15 of 3 | mantua
# Procssing Record 16 of 3 | nelson bay
# Procssing Record 17 of 3 | nyamuswa
# Procssing Record 18 of 3 | nueva imperial
# Procssing Record 19 of 3 | bethel
# Procssing Record 20 of 3 | mount gambier
# Procssing Record 21 of 3 | pahrump
# Procssing Record 22 of 3 | atuona
# Procssing Record 23 of 3 | safwah
# Procssing Record 24 of 3 | da nang
# Procssing Record 25 of 3 | kerman
# Procssing Record 26 of 3 | bandarbeyla
# Procssing Record 27 of 3 | sam chuk
# Procssing Record 28 of 3 | labuhan
# Procssing Record 29 of 3 | bilma
# Procssing Record 30 of 3 | chokurdakh
# Procssing Record 31 of 3 | kathmandu
# Procssing Record 32 of 3 | pecos
# Procssing Record 33 of 3 | itaobim
# Procssing Record 34 of 3 | sabang
# Procssing Record 35 of 3 | hamilton
# Procssing Record 36 of 3 | grindavik
# Procssing Record 37 of 3 | semnan
# Procssing Record 38 of 3 | launceston
# Procssing Record 39 of 3 | nanortalik
# Procssing Record 40 of 3 | tuy hoa
# Procssing Record 41 of 3 | bairnsdale
# Procssing Record 42 of 3 | hofn
# Procssing Record 43 of 3 | bubaque
# Procssing Record 44 of 3 | yangmei
# Procssing Record 45 of 3 | jiancheng
# Procssing Record 46 of 3 | henties bay
# Procssing Record 47 of 3 | tuggurt
# Procssing Record 48 of 3 | dori
# Procssing Record 49 of 3 | pervomayskoye
# Procssing Record 50 of 3 | billings
# Procssing Record 1 of 4 | abonnema
# Procssing Record 2 of 4 | amderma
# Procssing Record 3 of 4 | gawler
# Procssing Record 4 of 4 | benguela
# Procssing Record 5 of 4 | rorvik
# Procssing Record 6 of 4 | kokopo
# Procssing Record 7 of 4 | aasiaat
# Procssing Record 8 of 4 | saint-louis
# Procssing Record 9 of 4 | alofi
# Procssing Record 10 of 4 | chuy
# Procssing Record 11 of 4 | piacabucu
# Procssing Record 12 of 4 | okha
# Procssing Record 13 of 4 | santa rosa
# Procssing Record 14 of 4 | zhigansk
# Procssing Record 15 of 4 | port-cartier
# Procssing Record 16 of 4 | hilo
# Procssing Record 17 of 4 | balykshi
# Procssing Record 18 of 4 | butaritari
# Procssing Record 19 of 4 | yilan
# Procssing Record 20 of 4 | bengkulu
# Procssing Record 21 of 4 | kurilsk
# Procssing Record 22 of 4 | huarmey
# Procssing Record 23 of 4 | shillong
# Procssing Record 24 of 4 | tasiilaq
# Procssing Record 25 of 4 | kahului
# Procssing Record 26 of 4 | itapuranga
# Procssing Record 27 of 4 | ponta do sol
# Procssing Record 28 of 4 | ust-nera
# Procssing Record 29 of 4 | hobyo
# Procssing Record 30 of 4 | hithadhoo
# Procssing Record 31 of 4 | cherskiy
# Procssing Record 32 of 4 | coquimbo
# Procssing Record 33 of 4 | te anau
# Procssing Record 34 of 4 | ancud
# Procssing Record 35 of 4 | batemans bay
# Procssing Record 36 of 4 | lebu
# Procssing Record 37 of 4 | new norfolk
# Procssing Record 38 of 4 | kaoma
# Procssing Record 39 of 4 | fort nelson
# Procssing Record 40 of 4 | namwala
# Procssing Record 41 of 4 | tateyama
# Procssing Record 42 of 4 | geraldton
# Procssing Record 43 of 4 | bridlington
# Procssing Record 44 of 4 | namibe
# Procssing Record 45 of 4 | ituni
# Procssing Record 46 of 4 | phalaborwa
# Procssing Record 47 of 4 | xining
# Procssing Record 48 of 4 | attawapiskat
# Procssing Record 49 of 4 | moerai
# Procssing Record 50 of 4 | lompoc
# Procssing Record 1 of 5 | plettenberg bay
# Procssing Record 2 of 5 | cabo san lucas
# Procssing Record 3 of 5 | fortuna
# Procssing Record 4 of 5 | puerto cabezas
# Procssing Record 5 of 5 | gamba
# Procssing Record 6 of 5 | balclutha
# Procssing Record 7 of 5 | hammerfest
# Procssing Record 8 of 5 | lata
# Procssing Record 9 of 5 | shingu
# Procssing Record 10 of 5 | kodiak
# Procssing Record 11 of 5 | dikson
# Procssing Record 12 of 5 | khonuu
# Procssing Record 13 of 5 | tsihombe
# Procssing Record 14 of 5 | ruatoria
# Procssing Record 15 of 5 | kudahuvadhoo
# Procssing Record 16 of 5 | hambantota
# Procssing Record 17 of 5 | gerash
# Procssing Record 18 of 5 | cermik
# Procssing Record 19 of 5 | maniitsoq
# Procssing Record 20 of 5 | lethem
# Procssing Record 21 of 5 | rawson
# Procssing Record 22 of 5 | kamenka
# Procssing Record 23 of 5 | margate
# Procssing Record 24 of 5 | saint-philippe
# Procssing Record 25 of 5 | vanimo
# Procssing Record 26 of 5 | victoria
# Procssing Record 27 of 5 | namatanai
# Procssing Record 28 of 5 | brae
# Procssing Record 29 of 5 | saint-joseph
# Procssing Record 30 of 5 | sigli
# Procssing Record 31 of 5 | vila
# Procssing Record 32 of 5 | cap malheureux
# Procssing Record 33 of 5 | vila velha
# Procssing Record 34 of 5 | youghal
# Procssing Record 35 of 5 | lagoa
# Procssing Record 36 of 5 | alice springs
# Procssing Record 37 of 5 | salalah
# Procssing Record 38 of 5 | souillac
# Procssing Record 39 of 5 | inhambane
# Procssing Record 40 of 5 | rtishchevo
# Procssing Record 41 of 5 | torbay
# Procssing Record 42 of 5 | sentyabrskiy
# Procssing Record 43 of 5 | arkadelphia
# Procssing Record 44 of 5 | kruisfontein
# Procssing Record 45 of 5 | nizhniy kuranakh
# Procssing Record 46 of 5 | pousat
# Procssing Record 47 of 5 | kulhudhuffushi
# Procssing Record 48 of 5 | acapulco
# Procssing Record 49 of 5 | flinders
# Procssing Record 50 of 5 | karkaralinsk
# Procssing Record 1 of 6 | kaitangata
# Procssing Record 2 of 6 | chumikan
# Procssing Record 3 of 6 | mys shmidta
# Procssing Record 4 of 6 | teguldet
# Procssing Record 5 of 6 | grand gaube
# Procssing Record 6 of 6 | saskylakh
# Procssing Record 7 of 6 | onega
# Procssing Record 8 of 6 | umm kaddadah
# Procssing Record 9 of 6 | portland
# Procssing Record 10 of 6 | ihosy
# Procssing Record 11 of 6 | rio grande
# Procssing Record 12 of 6 | kloulklubed
# Procssing Record 13 of 6 | georgetown
# Procssing Record 14 of 6 | karlovo
# Procssing Record 15 of 6 | pisco
# Procssing Record 16 of 6 | kavieng
# Procssing Record 17 of 6 | puerto baquerizo moreno
# Procssing Record 18 of 6 | savannakhet
# Procssing Record 19 of 6 | ladario
# Procssing Record 20 of 6 | traverse city
# Procssing Record 21 of 6 | nantucket
# Procssing Record 22 of 6 | piet retief
# Procssing Record 23 of 6 | padang
# Procssing Record 24 of 6 | severo-kurilsk
# Procssing Record 25 of 6 | andevoranto
# Procssing Record 26 of 6 | oktyabrskoye
# Procssing Record 27 of 6 | bhuj
# Procssing Record 28 of 6 | pavlodar
# Procssing Record 29 of 6 | ayan
# Procssing Record 30 of 6 | huambo
# Procssing Record 31 of 6 | caravelas
# Procssing Record 32 of 6 | sitka
# Procssing Record 33 of 6 | banyo
# Procssing Record 34 of 6 | longavi
# Procssing Record 35 of 6 | buochs
# Procssing Record 36 of 6 | drexel heights
# Procssing Record 37 of 6 | klaksvik
# Procssing Record 38 of 6 | surat thani
# Procssing Record 39 of 6 | qasigiannguit
# Procssing Record 40 of 6 | manggar
# Procssing Record 41 of 6 | aksarka
# Procssing Record 42 of 6 | saint-augustin
# Procssing Record 43 of 6 | ejura
# Procssing Record 44 of 6 | tabou
# Procssing Record 45 of 6 | ankara
# Procssing Record 46 of 6 | aklavik
# Procssing Record 47 of 6 | whitehorse
# Procssing Record 48 of 6 | sibu
# Procssing Record 49 of 6 | pangnirtung
# Procssing Record 50 of 6 | santa cruz de la palma
# Procssing Record 1 of 7 | simpang
# Procssing Record 2 of 7 | sakaiminato
# Procssing Record 3 of 7 | grand river south east
# Procssing Record 4 of 7 | vestmanna
# Procssing Record 5 of 7 | palmer
# Procssing Record 6 of 7 | aubergenville
# Procssing Record 7 of 7 | chapais
# Procssing Record 8 of 7 | aksu
# Procssing Record 9 of 7 | poum
# Procssing Record 10 of 7 | khuzdar
# Procssing Record 11 of 7 | dawlatabad
# Procssing Record 12 of 7 | yuzhno-yeniseyskiy
# Procssing Record 13 of 7 | shenjiamen
# Procssing Record 14 of 7 | nabire
# Procssing Record 15 of 7 | nyurba
# Procssing Record 16 of 7 | louisbourg
# Procssing Record 17 of 7 | lakatoro
# Procssing Record 18 of 7 | marawi
# Procssing Record 19 of 7 | lorengau
# Procssing Record 20 of 7 | dwarka
# Procssing Record 21 of 7 | candido mendes
# Procssing Record 22 of 7 | ballina
# Procssing Record 23 of 7 | mackenzie
# Procssing Record 24 of 7 | umm lajj
# Procssing Record 25 of 7 | luanda
# Procssing Record 26 of 7 | sobolevo
# Procssing Record 27 of 7 | talnakh
# Procssing Record 28 of 7 | atherton
# Procssing Record 29 of 7 | chagda
# Procssing Record 30 of 7 | visby
# Procssing Record 31 of 7 | moree
# Procssing Record 32 of 7 | sibenik
# Procssing Record 33 of 7 | touros
# Procssing Record 34 of 7 | san carlos de bariloche
# Procssing Record 35 of 7 | shelburne
# Procssing Record 36 of 7 | skjervoy
# Procssing Record 37 of 7 | lasa
# Procssing Record 38 of 7 | kostomuksha
# Procssing Record 39 of 7 | bereda
# Procssing Record 40 of 7 | oxford
# Procssing Record 41 of 7 | hay river
# Procssing Record 42 of 7 | kodinsk
# Procssing Record 43 of 7 | ca mau
# Procssing Record 44 of 7 | benghazi
# Procssing Record 45 of 7 | ahipara
# Procssing Record 46 of 7 | paka
# Procssing Record 47 of 7 | pringsewu
# Procssing Record 48 of 7 | sept-iles
# Procssing Record 49 of 7 | dingle
# Procssing Record 50 of 7 | jaisalmer
# Procssing Record 1 of 8 | falun
# Procssing Record 2 of 8 | arroyo
# Procssing Record 3 of 8 | williston
# Procssing Record 4 of 8 | daru
# Procssing Record 5 of 8 | warwick
# Procssing Record 6 of 8 | yerbogachen
# Procssing Record 7 of 8 | san cristobal
# Procssing Record 8 of 8 | avera
# Procssing Record 9 of 8 | taltal
# Procssing Record 10 of 8 | nauta
# Procssing Record 11 of 8 | gao
# Procssing Record 12 of 8 | upata
# Procssing Record 13 of 8 | venado tuerto
# Procssing Record 14 of 8 | north platte
# Procssing Record 15 of 8 | ranong
# Procssing Record 16 of 8 | kashi
# Procssing Record 17 of 8 | saint-pierre
# Procssing Record 18 of 8 | kaseda
# Procssing Record 19 of 8 | morgan city
# Procssing Record 20 of 8 | qaqortoq
# Procssing Record 21 of 8 | kieta
# Procssing Record 22 of 8 | norman wells
# Procssing Record 23 of 8 | airai
# Procssing Record 24 of 8 | cavalcante
# Procssing Record 25 of 8 | kalininsk
# Procssing Record 26 of 8 | bambous virieux
# Procssing Record 27 of 8 | cayenne
# Procssing Record 28 of 8 | egvekinot
# Procssing Record 29 of 8 | bedesa
# Procssing Record 30 of 8 | tocopilla
# Procssing Record 31 of 8 | yarim
# Procssing Record 32 of 8 | narsaq
# Procssing Record 33 of 8 | faanui
# Procssing Record 34 of 8 | veraval
# Procssing Record 35 of 8 | nikolskoye
# Procssing Record 36 of 8 | dongying
# Procssing Record 37 of 8 | constitucion
# Procssing Record 38 of 8 | portachuelo
# Procssing Record 39 of 8 | ravar
# Procssing Record 40 of 8 | lyuban
# Procssing Record 41 of 8 | tahta
# Procssing Record 42 of 8 | newport
# Procssing Record 43 of 8 | srednekolymsk
# Procssing Record 44 of 8 | beyneu
# Procssing Record 45 of 8 | shenzhen
# Procssing Record 46 of 8 | bela
# Procssing Record 47 of 8 | lima
# Procssing Record 48 of 8 | havoysund
# Procssing Record 49 of 8 | artyk
# Procssing Record 50 of 8 | sataua
# Procssing Record 1 of 9 | paz de ariporo
# Procssing Record 2 of 9 | port shepstone
# Procssing Record 3 of 9 | ibra
# Procssing Record 4 of 9 | awjilah
# Procssing Record 5 of 9 | mehamn
# Procssing Record 6 of 9 | kautokeino
# Procssing Record 7 of 9 | lubao
# Procssing Record 8 of 9 | kalevala
# Procssing Record 9 of 9 | yangjiang
# Procssing Record 10 of 9 | sao joao da barra
# Procssing Record 11 of 9 | port hedland
# Procssing Record 12 of 9 | nemuro
# Procssing Record 13 of 9 | wamba
# Procssing Record 14 of 9 | havelock
# Procssing Record 15 of 9 | auki
# Procssing Record 16 of 9 | champerico
# Procssing Record 17 of 9 | martaban
# Procssing Record 18 of 9 | pevek
# Procssing Record 19 of 9 | bonthe
# Procssing Record 20 of 9 | envira
# Procssing Record 21 of 9 | hasaki
# Procssing Record 22 of 9 | westport
# Procssing Record 23 of 9 | broome
# Procssing Record 24 of 9 | coihaique
# Procssing Record 25 of 9 | dunedin
# Procssing Record 26 of 9 | mahebourg
# Procssing Record 27 of 9 | scarborough
# Procssing Record 28 of 9 | mackay
# Procssing Record 29 of 9 | redhakhol
# Procssing Record 30 of 9 | payson
# Procssing Record 31 of 9 | tessalit
# Procssing Record 32 of 9 | abu samrah
# Procssing Record 33 of 9 | asyut
# Procssing Record 34 of 9 | el alto
# Procssing Record 35 of 9 | iracoubo
# Procssing Record 36 of 9 | khandyga
# Procssing Record 37 of 9 | vagur
# Procssing Record 38 of 9 | vung tau
# Procssing Record 39 of 9 | lukang
# Procssing Record 40 of 9 | jinchang
# Procssing Record 41 of 9 | abu dhabi
# Procssing Record 42 of 9 | roald
# Procssing Record 43 of 9 | shcholkine
# Procssing Record 44 of 9 | leningradskiy
# Procssing Record 45 of 9 | sioux lookout
# Procssing Record 46 of 9 | boone
# Procssing Record 47 of 9 | manoel urbano
# Procssing Record 48 of 9 | wajir
# Procssing Record 49 of 9 | satara
# Procssing Record 50 of 9 | chernyshevskiy
# Procssing Record 1 of 10 | macaboboni
# Procssing Record 2 of 10 | cagayan de tawi-tawi
# Procssing Record 3 of 10 | phayao
# Procssing Record 4 of 10 | idah
# Procssing Record 5 of 10 | porto belo
# Procssing Record 6 of 10 | san patricio
# Procssing Record 7 of 10 | nagar karnul
# Procssing Record 8 of 10 | trincomalee
# Procssing Record 9 of 10 | upernavik
# Procssing Record 10 of 10 | samusu
# Procssing Record 11 of 10 | boa vista
# Procssing Record 12 of 10 | samarai
# Procssing Record 13 of 10 | canaries
# Procssing Record 14 of 10 | sechura
# Procssing Record 15 of 10 | najran
# Procssing Record 16 of 10 | fort saint james
# Procssing Record 17 of 10 | sambava
# Procssing Record 18 of 10 | tarabuco
# Procssing Record 19 of 10 | mezen
# Procssing Record 20 of 10 | dongsheng
# Procssing Record 21 of 10 | nicoya
# Procssing Record 22 of 10 | bijar
# Procssing Record 23 of 10 | beloha
# Procssing Record 24 of 10 | safaga
# Procssing Record 25 of 10 | port augusta
# Procssing Record 26 of 10 | fallon
# Procssing Record 27 of 10 | los llanos de aridane
# Procssing Record 28 of 10 | botshabelo
# Procssing Record 29 of 10 | matsanga
# Procssing Record 30 of 10 | merta
# Procssing Record 31 of 10 | balsas
# Procssing Record 32 of 10 | reforma
# Procssing Record 33 of 10 | itoman
# Procssing Record 34 of 10 | ongandjera
# Procssing Record 35 of 10 | umba
# Procssing Record 36 of 10 | san quintin
# Procssing Record 37 of 10 | mudyuga
# Procssing Record 38 of 10 | buala
# Procssing Record 39 of 10 | alta floresta
# Procssing Record 40 of 10 | svetlaya
# Procssing Record 41 of 10 | den helder
# Procssing Record 42 of 10 | maneadero
# Procssing Record 43 of 10 | leinefelde
# Procssing Record 44 of 10 | honiara
# Procssing Record 45 of 10 | artyom
# Procssing Record 46 of 10 | bacolod
# Procssing Record 47 of 10 | xuddur
# Procssing Record 48 of 10 | wanganui
# Procssing Record 49 of 10 | rantepao
# Procssing Record 50 of 10 | samfya
# Procssing Record 1 of 11 | hirara
# Procssing Record 2 of 11 | berlevag
# Procssing Record 3 of 11 | komsomolskiy
# Procssing Record 4 of 11 | anar darreh
# Procssing Record 5 of 11 | morris
# Procssing Record 6 of 11 | camana
# Procssing Record 7 of 11 | college
# Procssing Record 8 of 11 | javanrud
# Procssing Record 9 of 11 | bagdarin
# Procssing Record 10 of 11 | naze
# Procssing Record 11 of 11 | maxixe
# Procssing Record 12 of 11 | port hardy
# Procssing Record 13 of 11 | perbaungan
# Procssing Record 14 of 11 | bajil
# Procssing Record 15 of 11 | springbok
# Procssing Record 16 of 11 | codrington
# Procssing Record 17 of 11 | manzhouli
# Procssing Record 18 of 11 | tumpat
# Procssing Record 19 of 11 | igrim
# Procssing Record 20 of 11 | cam ranh
# Procssing Record 21 of 11 | adrar
# Procssing Record 22 of 11 | saldanha
# Procssing Record 23 of 11 | hualmay
# Procssing Record 24 of 11 | ingham
# Procssing Record 25 of 11 | barwadih
# Procssing Record 26 of 11 | laguna
# Procssing Record 27 of 11 | kawana waters
# Procssing Record 28 of 11 | barentsburg
# Procssing Record 29 of 11 | bathsheba
# Procssing Record 30 of 11 | inirida
# Procssing Record 31 of 11 | port elizabeth
# Procssing Record 32 of 11 | albion
# Procssing Record 33 of 11 | campeche
# Procssing Record 34 of 11 | usinsk
# Procssing Record 35 of 11 | kysyl-syr
# Procssing Record 36 of 11 | perigueux
# Procssing Record 37 of 11 | grand forks
# Procssing Record 38 of 11 | gazanjyk
# Procssing Record 39 of 11 | tairua
# Procssing Record 40 of 11 | salta
# Procssing Record 41 of 11 | nosy varika
# Procssing Record 42 of 11 | pochutla
# Procssing Record 43 of 11 | sandur
# Procssing Record 44 of 11 | ambulu
# Procssing Record 45 of 11 | jyvaskyla
# Procssing Record 46 of 11 | oum hadjer
# Procssing Record 47 of 11 | paracuru
# Procssing Record 48 of 11 | lunenburg
# Procssing Record 49 of 11 | camrose
# Procssing Record 50 of 11 | dicabisagan
# Procssing Record 1 of 12 | jahanabad
# Procssing Record 2 of 12 | kutulik
# Procssing Record 3 of 12 | tumannyy
# Procssing Record 4 of 12 | palu
# Procssing Record 5 of 12 | vallenar
# Procssing Record 6 of 12 | sorong
# Procssing Record 7 of 12 | lindsay
# Procssing Record 8 of 12 | tura
# Procssing Record 9 of 12 | korla
# Procssing Record 10 of 12 | quang ngai
# Procssing Record 11 of 12 | erenhot
# Procssing Record 12 of 12 | badou
# Procssing Record 13 of 12 | kabinda
# Procssing Record 14 of 12 | karratha
# Procssing Record 15 of 12 | beni
# Procssing Record 16 of 12 | qandala
# Procssing Record 17 of 12 | hovd
# Procssing Record 18 of 12 | khani
# Procssing Record 19 of 12 | tiznit
# Procssing Record 20 of 12 | fairbanks
# Procssing Record 21 of 12 | tres lagoas
# Procssing Record 22 of 12 | fare
# Procssing Record 23 of 12 | shimoda
# Procssing Record 24 of 12 | abu zabad
# -----------------------------------
# Data Retrieval Complete
# -----------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict ={
    "City": city_name,
    "Country":country,
    "Date":date,
    "Humidity":humidity,
    "Lat":lat,
    "Lng":lng,
    "Max Temp": max_temp,
    "Wind Speed":wind_speed,
    "Cloudiness":cloudiness
}

# %%
weather_df = pd.DataFrame(weather_dict)
weather_df.head()
# Out:
#           City Country        Date  Humidity    Lat     Lng  Max Temp  \
# 0        Arman      RU  1578153185        76  59.70  150.17    267.64
# 1    Cape Town      ZA  1578152606        60 -33.93   18.42    299.26
# 2   Banda Aceh      ID  1578153033        92   5.56   95.32    295.97
# 3  Clyde River      CA  1578152858        67  70.47  -68.59    240.15
# 4        Kidal      ML  1578153061        14  18.44    1.41    295.41
#
#    Wind Speed  Cloudiness
# 0       13.33          99
# 1        6.20           0
# 2        2.06           0
# 3        2.60          75
# 4        6.82           2

# %%
weather_df.count()
# Out:
# City          574
# Country       574
# Date          574
# Humidity      574
# Lat           574
# Lng           574
# Max Temp      574
# Wind Speed    574
# Cloudiness    574
# dtype: int64

# %%
# save the weather_df to 
weather_df.to_csv(output_data_file)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
weather_Max_f = (weather_df["Max Temp"]-273.15)*(9/5)+32
# (278K − 273.15) × 9/5 + 32

# %%
plt.figure(figsize=(10,5))
plt.title('Latitude vs. Temperature Plot')
plt.scatter(weather_df['Lat'],weather_Max_f, marker = "o",alpha=0.5)
plt.xlabel("Latitude")
plt.ylabel("Temperature"+'(F)')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(10,5))
plt.title('Latitude vs. Humidity Plot')
plt.scatter(weather_df['Lat'],weather_df['Humidity'], marker = "o",alpha=.5, color="g")
plt.xlabel("Latitude")
plt.ylabel("Humidity"+'(%)')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(10,5))
plt.title('Latitude vs. Cloudiness Plot')
plt.scatter(weather_df['Lat'],weather_df['Cloudiness'], marker = "o", alpha=.5,color='purple')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness"+'(%)')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(10,5))
plt.title('Latitude vs. Wind Speed Plot')
plt.scatter(weather_df['Lat'],(weather_df['Wind Speed']*3), marker = "o",alpha=.5, color='brown')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed"+'(mph)')
plt.grid(True)
plt.show()

# %%
# 3 obsarvations need to be written as well.

# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup #
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import pprint


import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data_cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# cities
# Out:
# 623

# %%
# cities

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# creating empty lists to fill API data.
city_name=[]
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# %%
def get_weather(city, api_key):
    url = "http://api.openweathermap.org/data/2.5/weather"
    payload = {
        "appid": api_key,
        "q":city
    }
    r = requests.get(url,params=payload)
    if r.status_code == 200:
        return r.json()
    else: 
        return None

# %%
# getting data in json format.
all_cities_json = []
for city in cities:
    result = get_weather(city,api_key)
    if result: 
        all_cities_json.append(result)
# all_cities_json

# %%
# showing first 2 items of all the data in json format
all_cities_json[0:2]
# Out:
# [{'coord': {'lon': -68.31, 'lat': -54.81},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 282.15,
#    'feels_like': 275.77,
#    'temp_min': 282.15,
#    'temp_max': 282.15,
#    'pressure': 1007,
#    'humidity': 61},
#   'visibility': 10000,
#   'wind': {'speed': 6.7, 'deg': 230},
#   'clouds': {'all': 40},
#   'dt': 1578109023,
#   'sys': {'type': 1,
#    'id': 8303,
#    'country': 'AR',
#    'sunrise': 1578125035,
#    'sunset': 1578186701},
#   'timezone': -10800,
#   'id': 3833367,
#   'name': 'Ushuaia',
#   'cod': 200},
#  {'coord': {'lon': 138.6, 'lat': -33.21},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'model',
#   'main': {'temp': 298.57,
#    'feels_like': 292.88,
#    'temp_min': 298.57,
#    'temp_max': 298.57,
#    'pressure': 1013,
#    'humidity': 42,
#    'sea_level': 1013,
#    'grnd_level': 957},
#   'wind': {'speed': 8.82, 'deg': 195},
#   'clouds': {'all': 0},
#   'dt': 1578109502,
#   'sys': {'country': 'AU', 'sunrise': 1578080489, 'sunset': 1578131900},
#   'timezone': 37800,
#   'id': 2069194,
#   'name': 'Jamestown',
#   'cod': 200}]

# %%
print("Begining Data Retrieval")
print('-'*29)
count = 1  # counter to count the number of call for APIs. 
sets = 1  # counter to count the number of call sets.
t0 = time.time()
for e in range(len(all_cities_json)):
    try:
        print(f"Procssing Record {count} of {sets} | {cities[e]}")
        city_name.append(all_cities_json[e]['name'])
        country.append(all_cities_json[e]['sys']['country'])
        humidity.append(all_cities_json[e]['main']['humidity'])
        date.append(all_cities_json[e]['dt'])
        cloudiness.append(all_cities_json[e]['clouds']['all'])
        lat.append(all_cities_json[e]['coord']['lat'])
        lng.append(all_cities_json[e]['coord']['lon'])
        max_temp.append(all_cities_json[e]['main']['temp_max'])
        wind_speed.append(all_cities_json[e]['wind']['speed'])
        
        count += 1
            
    except Exception as ex:
        print(ex)
        err += 1
    if count == 51:
        t1 = time.time()
        count =1 
        sets +=1
        time.sleep(60-(t1-t0))
        t0=time.time()
    
print("City not found. Skipping...")
    
print('-'*35)
print("Data Retrieval Complete")
print('-'*35)
# Out:
# Begining Data Retrieval
# -----------------------------
# Procssing Record 1 of 1 | ushuaia
# City not found. Skipping...
# Procssing Record 2 of 1 | jamestown
# City not found. Skipping...
# Procssing Record 3 of 1 | mys shmidta
# City not found. Skipping...
# Procssing Record 4 of 1 | belushya guba
# Procssing Record 44 of 4 | tanete
# City not found. Skipping...
# Procssing Record 45 of 4 | vanimo
# City not found. Skipping...
# Procssing Record 46 of 4 | montgomery
# City not found. Skipping...
# Procssing Record 47 of 4 | sal rei
# City not found. Skipping...
# Procssing Record 48 of 4 | constitucion
# City not found. Skipping...
# Procssing Record 49 of 4 | ho
# City not found. Skipping...
# Procssing Record 50 of 4 | pio xii
# City not found. Skipping...
# Procssing Record 1 of 5 | mareeba
# City not found. Skipping...
# Procssing Record 2 of 5 | mar del plata
# City not found. Skipping...
# Procssing Record 3 of 5 | port macquarie
# City not found. Skipping...
# Procssing Record 4 of 5 | lima
# City not found. Skipping...
# Procssing Record 5 of 5 | hasaki
# City not found. Skipping...
# Procssing Record 6 of 5 | ghanzi
# City not found. Skipping...
# Procssing Record 7 of 5 | jalu
# City not found. Skipping...
# Procssing Record 8 of 5 | narsaq
# City not found. Skipping...
# Procssing Record 9 of 5 | klaksvik
# City not found. Skipping...
# Procssing Record 10 of 5 | hurricane
# City not found. Skipping...
# Procssing Record 11 of 5 | ternate
# City not found. Skipping...
# Procssing Record 12 of 5 | badin
# City not found. Skipping...
# Procssing Record 13 of 5 | bluff
# City not found. Skipping...
# Procssing Record 14 of 5 | madaoua
# City not found. Skipping...
# Procssing Record 15 of 5 | falealupo
# City not found. Skipping...
# Procssing Record 16 of 5 | santiago
# City not found. Skipping...
# Procssing Record 17 of 5 | auki
# City not found. Skipping...
# Procssing Record 18 of 5 | touros
# City not found. Skipping...
# Procssing Record 19 of 5 | plymouth
# City not found. Skipping...
# Procssing Record 20 of 5 | clyde river
# City not found. Skipping...
# Procssing Record 21 of 5 | terney
# City not found. Skipping...
# Procssing Record 22 of 5 | huarmey
# City not found. Skipping...
# Procssing Record 23 of 5 | husavik
# City not found. Skipping...
# Procssing Record 24 of 5 | amderma
# City not found. Skipping...
# Procssing Record 25 of 5 | warqla
# City not found. Skipping...
# Procssing Record 26 of 5 | hutchinson
# City not found. Skipping...
# Procssing Record 27 of 5 | pandan
# City not found. Skipping...
# Procssing Record 28 of 5 | kirovskiy
# City not found. Skipping...
# Procssing Record 29 of 5 | ferai
# City not found. Skipping...
# Procssing Record 30 of 5 | provost
# City not found. Skipping...
# Procssing Record 31 of 5 | kodiak
# City not found. Skipping...
# Procssing Record 32 of 5 | vidim
# City not found. Skipping...
# Procssing Record 33 of 5 | cabo san lucas
# City not found. Skipping...
# Procssing Record 34 of 5 | champerico
# City not found. Skipping...
# Procssing Record 35 of 5 | sitka
# City not found. Skipping...
# Procssing Record 36 of 5 | dwarka
# City not found. Skipping...
# Procssing Record 37 of 5 | east london
# City not found. Skipping...
# Procssing Record 38 of 5 | muyezerskiy
# City not found. Skipping...
# Procssing Record 39 of 5 | kyshtovka
# City not found. Skipping...
# Procssing Record 40 of 5 | anloga
# City not found. Skipping...
# Procssing Record 41 of 5 | sistranda
# City not found. Skipping...
# Procssing Record 42 of 5 | grand centre
# City not found. Skipping...
# Procssing Record 43 of 5 | puri
# City not found. Skipping...
# Procssing Record 44 of 5 | okha
# City not found. Skipping...
# Procssing Record 45 of 5 | nishihara
# City not found. Skipping...
# Procssing Record 46 of 5 | cedar city
# City not found. Skipping...
# Procssing Record 47 of 5 | vao
# City not found. Skipping...
# Procssing Record 48 of 5 | vieques
# City not found. Skipping...
# Procssing Record 49 of 5 | siderno
# City not found. Skipping...
# Procssing Record 50 of 5 | ostrovnoy
# City not found. Skipping...
# Procssing Record 1 of 6 | hohhot
# City not found. Skipping...
# Procssing Record 2 of 6 | north battleford
# City not found. Skipping...
# Procssing Record 3 of 6 | lufkin
# City not found. Skipping...
# Procssing Record 4 of 6 | samalaeulu
# City not found. Skipping...
# Procssing Record 5 of 6 | goderich
# City not found. Skipping...
# Procssing Record 6 of 6 | berlevag
# City not found. Skipping...
# Procssing Record 7 of 6 | bur gabo
# City not found. Skipping...
# Procssing Record 8 of 6 | formoso do araguaia
# City not found. Skipping...
# Procssing Record 9 of 6 | oranjemund
# City not found. Skipping...
# Procssing Record 10 of 6 | oriximina
# City not found. Skipping...
# Procssing Record 11 of 6 | haines junction
# City not found. Skipping...
# Procssing Record 12 of 6 | yabelo
# City not found. Skipping...
# Procssing Record 13 of 6 | kirakira
# City not found. Skipping...
# Procssing Record 14 of 6 | agua prieta
# City not found. Skipping...
# Procssing Record 15 of 6 | saleaula
# City not found. Skipping...
# Procssing Record 16 of 6 | alice springs
# City not found. Skipping...
# Procssing Record 17 of 6 | galich
# City not found. Skipping...
# Procssing Record 18 of 6 | kavieng
# City not found. Skipping...
# Procssing Record 19 of 6 | chabahar
# City not found. Skipping...
# Procssing Record 20 of 6 | hithadhoo
# City not found. Skipping...
# Procssing Record 21 of 6 | nyurba
# City not found. Skipping...
# Procssing Record 22 of 6 | torbay
# City not found. Skipping...
# Procssing Record 23 of 6 | maputo
# City not found. Skipping...
# Procssing Record 24 of 6 | tecoanapa
# City not found. Skipping...
# Procssing Record 25 of 6 | bambanglipuro
# City not found. Skipping...
# Procssing Record 26 of 6 | saint-raymond
# City not found. Skipping...
# Procssing Record 27 of 6 | johnstown
# City not found. Skipping...
# Procssing Record 28 of 6 | raudeberg
# City not found. Skipping...
# Procssing Record 29 of 6 | bilma
# City not found. Skipping...
# Procssing Record 30 of 6 | sinnamary
# City not found. Skipping...
# Procssing Record 31 of 6 | algeciras
# City not found. Skipping...
# Procssing Record 32 of 6 | porto velho
# City not found. Skipping...
# Procssing Record 33 of 6 | sabang
# City not found. Skipping...
# Procssing Record 34 of 6 | dikson
# City not found. Skipping...
# Procssing Record 35 of 6 | rungata
# City not found. Skipping...
# Procssing Record 36 of 6 | broome
# City not found. Skipping...
# Procssing Record 37 of 6 | virginia beach
# City not found. Skipping...
# Procssing Record 38 of 6 | san quintin
# City not found. Skipping...
# Procssing Record 39 of 6 | fort nelson
# City not found. Skipping...
# Procssing Record 40 of 6 | kefalos
# City not found. Skipping...
# Procssing Record 41 of 6 | sladkovo
# City not found. Skipping...
# Procssing Record 42 of 6 | tokur
# City not found. Skipping...
# Procssing Record 43 of 6 | tigil
# City not found. Skipping...
# Procssing Record 44 of 6 | soto la marina
# City not found. Skipping...
# Procssing Record 45 of 6 | artyk
# City not found. Skipping...
# Procssing Record 46 of 6 | aksarka
# City not found. Skipping...
# Procssing Record 47 of 6 | san cristobal
# City not found. Skipping...
# Procssing Record 48 of 6 | cockburn harbour
# City not found. Skipping...
# Procssing Record 49 of 6 | bud
# City not found. Skipping...
# Procssing Record 50 of 6 | hyeres
# City not found. Skipping...
# Procssing Record 1 of 7 | belyy yar
# City not found. Skipping...
# Procssing Record 2 of 7 | necochea
# City not found. Skipping...
# Procssing Record 3 of 7 | aripuana
# City not found. Skipping...
# Procssing Record 4 of 7 | gayeri
# City not found. Skipping...
# Procssing Record 5 of 7 | erdemli
# City not found. Skipping...
# Procssing Record 6 of 7 | ixtapa
# City not found. Skipping...
# Procssing Record 7 of 7 | makakilo city
# City not found. Skipping...
# Procssing Record 8 of 7 | attawapiskat
# City not found. Skipping...
# Procssing Record 9 of 7 | america dourada
# City not found. Skipping...
# Procssing Record 10 of 7 | vysokogornyy
# City not found. Skipping...
# Procssing Record 11 of 7 | batemans bay
# City not found. Skipping...
# Procssing Record 12 of 7 | buraydah
# City not found. Skipping...
# Procssing Record 13 of 7 | bere
# City not found. Skipping...
# Procssing Record 14 of 7 | turbat
# City not found. Skipping...
# Procssing Record 15 of 7 | esperance
# City not found. Skipping...
# Procssing Record 16 of 7 | galle
# City not found. Skipping...
# Procssing Record 17 of 7 | leninskoye
# City not found. Skipping...
# Procssing Record 18 of 7 | ilulissat
# City not found. Skipping...
# Procssing Record 19 of 7 | vila
# City not found. Skipping...
# Procssing Record 20 of 7 | guerrero negro
# City not found. Skipping...
# Procssing Record 21 of 7 | frankfurt
# City not found. Skipping...
# Procssing Record 22 of 7 | tiksi
# City not found. Skipping...
# Procssing Record 23 of 7 | magnitka
# City not found. Skipping...
# Procssing Record 24 of 7 | grand gaube
# City not found. Skipping...
# Procssing Record 25 of 7 | nome
# City not found. Skipping...
# Procssing Record 26 of 7 | tual
# City not found. Skipping...
# Procssing Record 27 of 7 | carangola
# City not found. Skipping...
# Procssing Record 28 of 7 | chagda
# City not found. Skipping...
# Procssing Record 29 of 7 | half moon bay
# City not found. Skipping...
# Procssing Record 30 of 7 | jiazi
# City not found. Skipping...
# Procssing Record 31 of 7 | ahumada
# City not found. Skipping...
# Procssing Record 32 of 7 | tsihombe
# City not found. Skipping...
# Procssing Record 33 of 7 | nadym
# City not found. Skipping...
# Procssing Record 34 of 7 | lingao
# City not found. Skipping...
# Procssing Record 35 of 7 | srednekolymsk
# City not found. Skipping...
# Procssing Record 36 of 7 | los llanos de aridane
# City not found. Skipping...
# Procssing Record 29 of 10 | antofagasta
# City not found. Skipping...
# Procssing Record 30 of 10 | smithers
# City not found. Skipping...
# Procssing Record 31 of 10 | victor harbor
# City not found. Skipping...
# Procssing Record 32 of 10 | ust-kuyga
# City not found. Skipping...
# Procssing Record 33 of 10 | bedele
# City not found. Skipping...
# Procssing Record 34 of 10 | sayyan
# City not found. Skipping...
# Procssing Record 35 of 10 | neiafu
# City not found. Skipping...
# Procssing Record 36 of 10 | bumba
# City not found. Skipping...
# Procssing Record 37 of 10 | nanortalik
# City not found. Skipping...
# Procssing Record 38 of 10 | port hedland
# City not found. Skipping...
# Procssing Record 39 of 10 | dongying
# City not found. Skipping...
# Procssing Record 40 of 10 | texarkana
# City not found. Skipping...
# Procssing Record 41 of 10 | emerald
# City not found. Skipping...
# Procssing Record 42 of 10 | tortoli
# City not found. Skipping...
# Procssing Record 43 of 10 | bissora
# City not found. Skipping...
# Procssing Record 44 of 10 | beruwala
# City not found. Skipping...
# Procssing Record 45 of 10 | vaitupu
# City not found. Skipping...
# Procssing Record 46 of 10 | tumannyy
# City not found. Skipping...
# Procssing Record 47 of 10 | bandar
# City not found. Skipping...
# Procssing Record 48 of 10 | sao gabriel da cachoeira
# City not found. Skipping...
# Procssing Record 49 of 10 | astana
# City not found. Skipping...
# Procssing Record 50 of 10 | nouadhibou

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict ={
    "City": city_name,
    "Country":country,
    "Date":date,
    "Humidity":humidity,
    "Lat":lat,
    "Lng":lng,
    "Max Temp": max_temp,
    "Wind Speed":wind_speed,
    "Cloudiness":cloudiness
}

# %%
weather_df = pd.DataFrame(weather_dict)
weather_df.head()

# %%
weather_df.count()

# %%
# save the weather_df to 
weather_df.to_csv(output_data_file)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
weather_Max_f = (weather_df["Max Temp"]-273.15)*(9/5)+32
# (278K − 273.15) × 9/5 + 32

# %%
plt.figure(figsize=(10,5))
plt.title('Latitude vs. Temperature Plot')
plt.scatter(weather_df['Lat'],weather_Max_f, marker = "o",alpha=0.5)
plt.xlabel("Latitude")
plt.ylabel("Temperature"+'(F)')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(10,5))
plt.title('Latitude vs. Humidity Plot')
plt.scatter(weather_df['Lat'],weather_df['Humidity'], marker = "o",alpha=.5, color="g")
plt.xlabel("Latitude")
plt.ylabel("Humidity"+'(%)')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(10,5))
plt.title('Latitude vs. Cloudiness Plot')
plt.scatter(weather_df['Lat'],weather_df['Cloudiness'], marker = "o", alpha=.5,color='purple')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness"+'(%)')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(10,5))
plt.title('Latitude vs. Wind Speed Plot')
plt.scatter(weather_df['Lat'],(weather_df['Wind Speed']*3), marker = "o",alpha=.5, color='brown')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed"+'(mph)')
plt.grid(True)
plt.show()

# %%
# 3 obsarvations need to be written as well.

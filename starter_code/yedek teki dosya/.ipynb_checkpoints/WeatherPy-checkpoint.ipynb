# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup #
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import pprint


import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data_cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# cities
# Out:
# 606

# %%
# cities

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# creating empty lists to fill API data.
city_name=[]
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# %%
def get_weather(city, api_key):
    url = "http://api.openweathermap.org/data/2.5/weather"
    payload = {
        "appid": api_key,
        "q":city
    }
    r = requests.get(url,params=payload)
    if r.status_code == 200:
        return r.json()
    else: 
        return None

# %%
all_cities_json = []
for city in cities:
    result = get_weather(city,api_key)
    if result: 
        all_cities_json.append(result)

# %%
# all json format of cities.
# all_cities_json[0:2]

# %%
print("Begining Data Retrieval")
print('-'*29)
num = 1
for e in range(len(all_cities_json)):
    city_name.append(all_cities_json[e]['name'])
    country.append(all_cities_json[e]['sys']['country'])
    humidity.append(all_cities_json[e]['main']['humidity'])
    date.append(all_cities_json[e]['dt'])
    cloudiness.append(all_cities_json[e]['clouds']['all'])
    lat.append(all_cities_json[e]['coord']['lat'])
    lng.append(all_cities_json[e]['coord']['lon'])
    max_temp.append(all_cities_json[e]['main']['temp_max'])
    wind_speed.append(all_cities_json[e]['wind']['speed'])
    try:
        print(f"Procssing Record {num} of Set 1 | {cities[e]}")
        num += 1
    except:
        print("City not found. Skipping...")
    continue
    
print('-'*35)
print("Data Retrieval Complete")
print('-'*35)
# Out:
# Begining Data Retrieval
# -----------------------------
# Procssing Record 1 of Set 1 | komsomolskiy
# Procssing Record 2 of Set 1 | qaanaaq
# Procssing Record 3 of Set 1 | duku
# Procssing Record 4 of Set 1 | kudahuvadhoo
# Procssing Record 5 of Set 1 | port alfred
# Procssing Record 6 of Set 1 | saldanha
# Procssing Record 7 of Set 1 | sao filipe
# Procssing Record 8 of Set 1 | puerto del rosario
# Procssing Record 9 of Set 1 | olinda
# Procssing Record 10 of Set 1 | carnarvon
# Procssing Record 11 of Set 1 | rungata
# Procssing Record 12 of Set 1 | bluff
# Procssing Record 13 of Set 1 | marienburg
# Procssing Record 14 of Set 1 | hermanus
# Procssing Record 15 of Set 1 | hobart
# Procssing Record 16 of Set 1 | mataura
# Procssing Record 17 of Set 1 | busselton
# Procssing Record 18 of Set 1 | new norfolk
# Procssing Record 19 of Set 1 | port blair
# Procssing Record 20 of Set 1 | phon
# Procssing Record 21 of Set 1 | konevo
# Procssing Record 22 of Set 1 | rikitea
# Procssing Record 23 of Set 1 | barawe
# Procssing Record 24 of Set 1 | illoqqortoormiut
# Procssing Record 25 of Set 1 | prince rupert
# Procssing Record 26 of Set 1 | ushuaia
# Procssing Record 27 of Set 1 | hirara
# Procssing Record 28 of Set 1 | russell
# Procssing Record 29 of Set 1 | tyrma
# Procssing Record 30 of Set 1 | port elizabeth
# Procssing Record 31 of Set 1 | airai
# Procssing Record 32 of Set 1 | miraflores
# Procssing Record 33 of Set 1 | bilibino
# Procssing Record 34 of Set 1 | sangmelima
# Procssing Record 35 of Set 1 | sola
# Procssing Record 36 of Set 1 | souillac
# Procssing Record 37 of Set 1 | cherskiy
# Procssing Record 38 of Set 1 | jamestown
# Procssing Record 39 of Set 1 | tiksi
# Procssing Record 40 of Set 1 | kavaratti
# Procssing Record 41 of Set 1 | albany
# Procssing Record 42 of Set 1 | kavieng
# Procssing Record 43 of Set 1 | taolanaro
# Procssing Record 44 of Set 1 | rognan
# Procssing Record 45 of Set 1 | kaitangata
# Procssing Record 46 of Set 1 | marcona
# Procssing Record 47 of Set 1 | punta arenas
# Procssing Record 48 of Set 1 | hay river
# Procssing Record 49 of Set 1 | matelandia
# Procssing Record 50 of Set 1 | georgetown
# Procssing Record 51 of Set 1 | vao
# Procssing Record 52 of Set 1 | guerrero negro
# Procssing Record 53 of Set 1 | ngerengere
# Procssing Record 54 of Set 1 | kosa
# Procssing Record 55 of Set 1 | sechura
# Procssing Record 56 of Set 1 | constitucion
# Procssing Record 57 of Set 1 | barrow
# Procssing Record 58 of Set 1 | butaritari
# Procssing Record 59 of Set 1 | poum
# Procssing Record 60 of Set 1 | atuona
# Procssing Record 61 of Set 1 | touros
# Procssing Record 62 of Set 1 | koson
# Procssing Record 63 of Set 1 | oktyabrskoye
# Procssing Record 64 of Set 1 | naftah
# Procssing Record 65 of Set 1 | qaqortoq
# Procssing Record 66 of Set 1 | buchanan
# Procssing Record 67 of Set 1 | bumba
# Procssing Record 68 of Set 1 | kulhudhuffushi
# Procssing Record 69 of Set 1 | bolungarvik
# Procssing Record 70 of Set 1 | naze
# Procssing Record 71 of Set 1 | miram shah
# Procssing Record 72 of Set 1 | cape town
# Procssing Record 73 of Set 1 | codrington
# Procssing Record 74 of Set 1 | dhidhdhoo
# Procssing Record 75 of Set 1 | sheoganj
# Procssing Record 76 of Set 1 | kadykchan
# Procssing Record 77 of Set 1 | viedma
# Procssing Record 78 of Set 1 | katsuura
# Procssing Record 79 of Set 1 | cidreira
# Procssing Record 80 of Set 1 | khatanga
# Procssing Record 81 of Set 1 | cuamba
# Procssing Record 82 of Set 1 | shatrovo
# Procssing Record 83 of Set 1 | east london
# Procssing Record 84 of Set 1 | bara
# Procssing Record 85 of Set 1 | huoqiu
# Procssing Record 86 of Set 1 | puerto ayora
# Procssing Record 87 of Set 1 | benghazi
# Procssing Record 88 of Set 1 | nanakuli
# Procssing Record 89 of Set 1 | pevek
# Procssing Record 90 of Set 1 | ancud
# Procssing Record 91 of Set 1 | clyde river
# Procssing Record 92 of Set 1 | bambous virieux
# Procssing Record 93 of Set 1 | orlik
# Procssing Record 94 of Set 1 | bethel
# Procssing Record 95 of Set 1 | lethem
# Procssing Record 96 of Set 1 | muborak
# Procssing Record 97 of Set 1 | port lincoln
# Procssing Record 98 of Set 1 | hithadhoo
# Procssing Record 99 of Set 1 | barentsburg
# Procssing Record 100 of Set 1 | havre-saint-pierre
# Procssing Record 101 of Set 1 | ruatoria
# Procssing Record 102 of Set 1 | hilo
# Procssing Record 103 of Set 1 | huichapan
# Procssing Record 104 of Set 1 | chokurdakh
# Procssing Record 105 of Set 1 | lorengau
# Procssing Record 106 of Set 1 | saskylakh
# Procssing Record 107 of Set 1 | cockburn town
# Procssing Record 108 of Set 1 | kongolo
# Procssing Record 109 of Set 1 | lompoc
# Procssing Record 110 of Set 1 | provideniya
# Procssing Record 111 of Set 1 | kapaa
# Procssing Record 112 of Set 1 | talnakh
# Procssing Record 113 of Set 1 | ostrovnoy
# Procssing Record 114 of Set 1 | aswan
# Procssing Record 115 of Set 1 | cayenne
# Procssing Record 116 of Set 1 | saint-philippe
# Procssing Record 117 of Set 1 | louisbourg
# Procssing Record 118 of Set 1 | tocantinopolis
# Procssing Record 119 of Set 1 | aloleng
# Procssing Record 120 of Set 1 | butterworth
# Procssing Record 121 of Set 1 | telixtac
# Procssing Record 122 of Set 1 | salalah
# Procssing Record 123 of Set 1 | victoria
# Procssing Record 124 of Set 1 | pochutla
# Procssing Record 125 of Set 1 | puerto baquerizo moreno
# Procssing Record 126 of Set 1 | somoto
# Procssing Record 127 of Set 1 | helena
# Procssing Record 128 of Set 1 | berlevag
# Procssing Record 129 of Set 1 | shitanjing
# Procssing Record 130 of Set 1 | nizhneyansk
# Procssing Record 131 of Set 1 | tsihombe
# Procssing Record 132 of Set 1 | zhaotong
# Procssing Record 133 of Set 1 | clearlake
# Procssing Record 134 of Set 1 | natchez
# Procssing Record 135 of Set 1 | huangchuan
# Procssing Record 136 of Set 1 | belushya guba
# Procssing Record 137 of Set 1 | cotonou
# Procssing Record 138 of Set 1 | meyungs
# Procssing Record 139 of Set 1 | evensk
# Procssing Record 140 of Set 1 | toora-khem
# Procssing Record 141 of Set 1 | avarua
# Procssing Record 142 of Set 1 | bredasdorp
# Procssing Record 143 of Set 1 | yatou
# Procssing Record 144 of Set 1 | arraial do cabo
# Procssing Record 145 of Set 1 | catamarca
# Procssing Record 146 of Set 1 | lavrentiya
# Procssing Record 147 of Set 1 | upernavik
# Procssing Record 148 of Set 1 | matara
# Procssing Record 149 of Set 1 | tuktoyaktuk
# Procssing Record 150 of Set 1 | sorvag
# Procssing Record 151 of Set 1 | thompson
# Procssing Record 152 of Set 1 | araouane
# Procssing Record 153 of Set 1 | nemuro
# Procssing Record 154 of Set 1 | yenagoa
# Procssing Record 155 of Set 1 | malwan
# Procssing Record 156 of Set 1 | iqaluit
# Procssing Record 157 of Set 1 | yumen
# Procssing Record 158 of Set 1 | shimoda
# Procssing Record 159 of Set 1 | borogontsy
# Procssing Record 160 of Set 1 | yellowknife
# Procssing Record 161 of Set 1 | luderitz
# Procssing Record 162 of Set 1 | severo-kurilsk
# Procssing Record 163 of Set 1 | praia da vitoria
# Procssing Record 164 of Set 1 | nisia floresta
# Procssing Record 165 of Set 1 | mar del plata
# Procssing Record 166 of Set 1 | nikolskoye
# Procssing Record 167 of Set 1 | vila velha
# Procssing Record 168 of Set 1 | dawei
# Procssing Record 169 of Set 1 | tevaitoa
# Procssing Record 170 of Set 1 | grand river south east
# Procssing Record 171 of Set 1 | mehamn
# Procssing Record 172 of Set 1 | kodiak
# Procssing Record 173 of Set 1 | attawapiskat
# Procssing Record 174 of Set 1 | troitskoye
# Procssing Record 175 of Set 1 | parvatipuram
# Procssing Record 176 of Set 1 | samusu
# Procssing Record 177 of Set 1 | lagunas
# Procssing Record 178 of Set 1 | ngunguru
# Procssing Record 179 of Set 1 | san patricio
# Procssing Record 180 of Set 1 | tautira
# Procssing Record 181 of Set 1 | borisoglebsk
# Procssing Record 182 of Set 1 | rio gallegos
# Procssing Record 183 of Set 1 | amapa
# Procssing Record 184 of Set 1 | balabac
# Procssing Record 185 of Set 1 | filadelfia
# Procssing Record 186 of Set 1 | atambua
# Procssing Record 187 of Set 1 | valparaiso
# Procssing Record 188 of Set 1 | henties bay
# Procssing Record 189 of Set 1 | pisco
# Procssing Record 190 of Set 1 | rjukan
# Procssing Record 191 of Set 1 | belmonte
# Procssing Record 192 of Set 1 | bahia honda
# Procssing Record 193 of Set 1 | broni
# Procssing Record 194 of Set 1 | norman wells
# Procssing Record 195 of Set 1 | narsaq
# Procssing Record 196 of Set 1 | torbay
# Procssing Record 197 of Set 1 | xapuri
# Procssing Record 198 of Set 1 | egvekinot
# Procssing Record 199 of Set 1 | kifri
# Procssing Record 200 of Set 1 | paithan
# Procssing Record 201 of Set 1 | rio grande
# Procssing Record 202 of Set 1 | mahebourg
# Procssing Record 203 of Set 1 | nizhniy kuranakh
# Procssing Record 204 of Set 1 | thano bula khan
# Procssing Record 205 of Set 1 | kindu
# Procssing Record 206 of Set 1 | sidi ali
# Procssing Record 207 of Set 1 | ribeira grande
# Procssing Record 208 of Set 1 | dukat
# Procssing Record 209 of Set 1 | kegayli
# Procssing Record 210 of Set 1 | mys shmidta
# Procssing Record 211 of Set 1 | guayaramerin
# Procssing Record 212 of Set 1 | esperance
# Procssing Record 213 of Set 1 | sorland
# Procssing Record 214 of Set 1 | bashtanka
# Procssing Record 215 of Set 1 | oyama
# Procssing Record 216 of Set 1 | tasiilaq
# Procssing Record 217 of Set 1 | dromolaxia
# Procssing Record 218 of Set 1 | hashtrud
# Procssing Record 219 of Set 1 | tabukiniberu
# Procssing Record 220 of Set 1 | lasa
# Procssing Record 221 of Set 1 | tahta
# Procssing Record 222 of Set 1 | outlook
# Procssing Record 223 of Set 1 | cuicatlan
# Procssing Record 224 of Set 1 | santa marta
# Procssing Record 225 of Set 1 | hofn
# Procssing Record 226 of Set 1 | gazimurskiy zavod
# Procssing Record 227 of Set 1 | nha trang
# Procssing Record 228 of Set 1 | leshukonskoye
# Procssing Record 229 of Set 1 | port-gentil
# Procssing Record 230 of Set 1 | caiaponia
# Procssing Record 231 of Set 1 | dikson
# Procssing Record 232 of Set 1 | hamilton
# Procssing Record 233 of Set 1 | usinsk
# Procssing Record 234 of Set 1 | kabinda
# Procssing Record 235 of Set 1 | pemangkat
# Procssing Record 236 of Set 1 | nouadhibou
# Procssing Record 237 of Set 1 | kimbe
# Procssing Record 238 of Set 1 | oranjemund
# Procssing Record 239 of Set 1 | kushmurun
# Procssing Record 240 of Set 1 | vaini
# Procssing Record 241 of Set 1 | tecoanapa
# Procssing Record 242 of Set 1 | plettenberg bay
# Procssing Record 243 of Set 1 | verkhnevilyuysk
# Procssing Record 244 of Set 1 | petropavlovsk-kamchatskiy
# Procssing Record 245 of Set 1 | longyearbyen
# Procssing Record 246 of Set 1 | saint-augustin
# Procssing Record 247 of Set 1 | laguna
# Procssing Record 248 of Set 1 | fairbanks
# Procssing Record 249 of Set 1 | manyana
# Procssing Record 250 of Set 1 | meulaboh
# Procssing Record 251 of Set 1 | mount isa
# Procssing Record 252 of Set 1 | kahului
# Procssing Record 253 of Set 1 | menongue
# Procssing Record 254 of Set 1 | bitung
# Procssing Record 255 of Set 1 | luanda
# Procssing Record 256 of Set 1 | xiamen
# Procssing Record 257 of Set 1 | shilovo
# Procssing Record 258 of Set 1 | redlands
# Procssing Record 259 of Set 1 | quatre cocos
# Procssing Record 260 of Set 1 | north bend
# Procssing Record 261 of Set 1 | karpathos
# Procssing Record 262 of Set 1 | maarianhamina
# Procssing Record 263 of Set 1 | fort nelson
# Procssing Record 264 of Set 1 | ilulissat
# Procssing Record 265 of Set 1 | ixtapa
# Procssing Record 266 of Set 1 | chuy
# Procssing Record 267 of Set 1 | old town
# Procssing Record 268 of Set 1 | puerto el triunfo
# Procssing Record 269 of Set 1 | yar-sale
# Procssing Record 270 of Set 1 | kutum
# Procssing Record 271 of Set 1 | tanout
# Procssing Record 272 of Set 1 | kalmunai
# Procssing Record 273 of Set 1 | vuktyl
# Procssing Record 274 of Set 1 | katobu
# Procssing Record 275 of Set 1 | gushi
# Procssing Record 276 of Set 1 | jalu
# Procssing Record 277 of Set 1 | sterling
# Procssing Record 278 of Set 1 | vestmannaeyjar
# Procssing Record 279 of Set 1 | slavyanka
# Procssing Record 280 of Set 1 | mayskiy
# Procssing Record 281 of Set 1 | margate
# Procssing Record 282 of Set 1 | dongsheng
# Procssing Record 283 of Set 1 | college
# Procssing Record 284 of Set 1 | colquechaca
# Procssing Record 285 of Set 1 | tabiauea
# Procssing Record 286 of Set 1 | fevralsk
# Procssing Record 287 of Set 1 | alofi
# Procssing Record 288 of Set 1 | bubaque
# Procssing Record 289 of Set 1 | nelson bay
# Procssing Record 290 of Set 1 | garowe
# Procssing Record 291 of Set 1 | okato
# Procssing Record 292 of Set 1 | ngukurr
# Procssing Record 293 of Set 1 | amderma
# Procssing Record 294 of Set 1 | dhali
# Procssing Record 295 of Set 1 | riyadh
# Procssing Record 296 of Set 1 | souflion
# Procssing Record 297 of Set 1 | ambajogai
# Procssing Record 298 of Set 1 | rakoshyno
# Procssing Record 299 of Set 1 | vaitupu
# Procssing Record 300 of Set 1 | newcastle
# Procssing Record 301 of Set 1 | sitka
# Procssing Record 302 of Set 1 | envira
# Procssing Record 303 of Set 1 | srednekolymsk
# Procssing Record 304 of Set 1 | san carlos del zulia
# Procssing Record 305 of Set 1 | chitungwiza
# Procssing Record 306 of Set 1 | ponta do sol
# Procssing Record 307 of Set 1 | javanrud
# Procssing Record 308 of Set 1 | izhma
# Procssing Record 309 of Set 1 | ahipara
# Procssing Record 310 of Set 1 | shelburne
# Procssing Record 311 of Set 1 | amposta
# Procssing Record 312 of Set 1 | port hedland
# Procssing Record 313 of Set 1 | koboldo
# Procssing Record 314 of Set 1 | lebu
# Procssing Record 315 of Set 1 | medvezhyegorsk
# Procssing Record 316 of Set 1 | algiers
# Procssing Record 317 of Set 1 | makokou
# Procssing Record 318 of Set 1 | vardo
# Procssing Record 319 of Set 1 | te anau
# Procssing Record 320 of Set 1 | zambezi
# Procssing Record 321 of Set 1 | puerto leguizamo
# Procssing Record 322 of Set 1 | kamenskoye
# Procssing Record 323 of Set 1 | ornskoldsvik
# Procssing Record 324 of Set 1 | banjar
# Procssing Record 325 of Set 1 | broome
# Procssing Record 326 of Set 1 | honiara
# Procssing Record 327 of Set 1 | los llanos de aridane
# Procssing Record 328 of Set 1 | tarudant
# Procssing Record 329 of Set 1 | bonavista
# Procssing Record 330 of Set 1 | lincoln
# Procssing Record 331 of Set 1 | saint anthony
# Procssing Record 332 of Set 1 | ulaanbaatar
# Procssing Record 333 of Set 1 | novomykolayivka
# Procssing Record 334 of Set 1 | san luis
# Procssing Record 335 of Set 1 | conde
# Procssing Record 336 of Set 1 | villa bruzual
# Procssing Record 337 of Set 1 | west odessa
# Procssing Record 338 of Set 1 | santander
# Procssing Record 339 of Set 1 | olafsvik
# Procssing Record 340 of Set 1 | saint-joseph
# Procssing Record 341 of Set 1 | cazaje
# Procssing Record 342 of Set 1 | flinders
# Procssing Record 343 of Set 1 | sheltozero
# Procssing Record 344 of Set 1 | takoradi
# Procssing Record 345 of Set 1 | chara
# Procssing Record 346 of Set 1 | cururupu
# Procssing Record 347 of Set 1 | nanning
# Procssing Record 348 of Set 1 | pathein
# Procssing Record 349 of Set 1 | comodoro rivadavia
# Procssing Record 350 of Set 1 | faya
# Procssing Record 351 of Set 1 | russellville
# Procssing Record 352 of Set 1 | hasaki
# Procssing Record 353 of Set 1 | sur
# Procssing Record 354 of Set 1 | juifang
# Procssing Record 355 of Set 1 | solnechnyy
# Procssing Record 356 of Set 1 | santa cruz de tenerife
# Procssing Record 357 of Set 1 | vilyuysk
# Procssing Record 358 of Set 1 | vila franca do campo
# Procssing Record 359 of Set 1 | ulagan
# Procssing Record 360 of Set 1 | fortuna
# Procssing Record 361 of Set 1 | morristown
# Procssing Record 362 of Set 1 | tilichiki
# Procssing Record 363 of Set 1 | nanortalik
# Procssing Record 364 of Set 1 | sinkat
# Procssing Record 365 of Set 1 | tambura
# Procssing Record 366 of Set 1 | itarema
# Procssing Record 367 of Set 1 | zyryanka
# Procssing Record 368 of Set 1 | san
# Procssing Record 369 of Set 1 | baiyin
# Procssing Record 370 of Set 1 | impfondo
# Procssing Record 371 of Set 1 | karasburg
# Procssing Record 372 of Set 1 | harper
# Procssing Record 373 of Set 1 | westport
# Procssing Record 374 of Set 1 | palabuhanratu
# Procssing Record 375 of Set 1 | serebryanyy bor
# Procssing Record 376 of Set 1 | beringovskiy
# Procssing Record 377 of Set 1 | kuruman
# Procssing Record 378 of Set 1 | nyurba
# Procssing Record 379 of Set 1 | escanaba
# Procssing Record 380 of Set 1 | huarmey
# Procssing Record 381 of Set 1 | tulungagung
# Procssing Record 382 of Set 1 | gazanjyk
# Procssing Record 383 of Set 1 | castro
# Procssing Record 384 of Set 1 | bengkulu
# Procssing Record 385 of Set 1 | kashan
# Procssing Record 386 of Set 1 | bardiyah
# Procssing Record 387 of Set 1 | fowa
# Procssing Record 388 of Set 1 | san jorge
# Procssing Record 389 of Set 1 | sao joao da barra
# Procssing Record 390 of Set 1 | bowen
# Procssing Record 391 of Set 1 | tuggurt
# Procssing Record 392 of Set 1 | coihaique
# Procssing Record 393 of Set 1 | kerman
# Procssing Record 394 of Set 1 | mukhen
# Procssing Record 395 of Set 1 | san juan del sur
# Procssing Record 396 of Set 1 | guadalupe y calvo
# Procssing Record 397 of Set 1 | awbari
# Procssing Record 398 of Set 1 | marica
# Procssing Record 399 of Set 1 | la palma
# Procssing Record 400 of Set 1 | adrar
# Procssing Record 401 of Set 1 | gboko
# Procssing Record 402 of Set 1 | half moon bay
# Procssing Record 403 of Set 1 | iquitos
# Procssing Record 404 of Set 1 | havelock
# Procssing Record 405 of Set 1 | grand-santi
# Procssing Record 406 of Set 1 | wum
# Procssing Record 407 of Set 1 | umm lajj
# Procssing Record 408 of Set 1 | sri aman
# Procssing Record 409 of Set 1 | sorong
# Procssing Record 410 of Set 1 | hervey bay
# Procssing Record 411 of Set 1 | strezhevoy
# Procssing Record 412 of Set 1 | bajil
# Procssing Record 413 of Set 1 | sentyabrskiy
# Procssing Record 414 of Set 1 | mabaruma
# Procssing Record 415 of Set 1 | santa rosa
# Procssing Record 416 of Set 1 | shancheng
# Procssing Record 417 of Set 1 | qixingtai
# Procssing Record 418 of Set 1 | rincon
# Procssing Record 419 of Set 1 | medea
# Procssing Record 420 of Set 1 | esmeraldas
# Procssing Record 421 of Set 1 | chai badan
# Procssing Record 422 of Set 1 | am timan
# Procssing Record 423 of Set 1 | ilanskiy
# Procssing Record 424 of Set 1 | talas
# Procssing Record 425 of Set 1 | sisimiut
# Procssing Record 426 of Set 1 | kamyshla
# Procssing Record 427 of Set 1 | tukrah
# Procssing Record 428 of Set 1 | waw
# Procssing Record 429 of Set 1 | leningradskiy
# Procssing Record 430 of Set 1 | edd
# Procssing Record 431 of Set 1 | vanavara
# Procssing Record 432 of Set 1 | lumberton
# Procssing Record 433 of Set 1 | umm jarr
# Procssing Record 434 of Set 1 | canutama
# Procssing Record 435 of Set 1 | halalo
# Procssing Record 436 of Set 1 | brae
# Procssing Record 437 of Set 1 | mecca
# Procssing Record 438 of Set 1 | hobyo
# Procssing Record 439 of Set 1 | camacha
# Procssing Record 440 of Set 1 | miri
# Procssing Record 441 of Set 1 | geraldton
# Procssing Record 442 of Set 1 | sinnamary
# Procssing Record 443 of Set 1 | astana
# Procssing Record 444 of Set 1 | lewiston
# Procssing Record 445 of Set 1 | masterton
# Procssing Record 446 of Set 1 | nuuk
# Procssing Record 447 of Set 1 | san andres
# Procssing Record 448 of Set 1 | havoysund
# Procssing Record 449 of Set 1 | bondoukou
# Procssing Record 450 of Set 1 | kokopo
# Procssing Record 451 of Set 1 | ilhabela
# Procssing Record 452 of Set 1 | hastings
# Procssing Record 453 of Set 1 | kruisfontein
# Procssing Record 454 of Set 1 | pacific grove
# Procssing Record 455 of Set 1 | saleaula
# Procssing Record 456 of Set 1 | lagoa
# Procssing Record 457 of Set 1 | zaragoza
# Procssing Record 458 of Set 1 | dingle
# Procssing Record 459 of Set 1 | sheregesh
# Procssing Record 460 of Set 1 | ejea de los caballeros
# Procssing Record 461 of Set 1 | torrijos
# Procssing Record 462 of Set 1 | faanui
# Procssing Record 463 of Set 1 | tranas
# Procssing Record 464 of Set 1 | tura
# Procssing Record 465 of Set 1 | tigil
# Procssing Record 466 of Set 1 | gold coast
# Procssing Record 467 of Set 1 | nautla
# Procssing Record 468 of Set 1 | nam tha
# Procssing Record 469 of Set 1 | chihuahua
# Procssing Record 470 of Set 1 | dong hoi
# Procssing Record 471 of Set 1 | chlorakas
# Procssing Record 472 of Set 1 | antofagasta
# Procssing Record 473 of Set 1 | yarada
# Procssing Record 474 of Set 1 | aykhal
# Procssing Record 475 of Set 1 | goderich
# Procssing Record 476 of Set 1 | darnah
# Procssing Record 477 of Set 1 | tuatapere
# Procssing Record 478 of Set 1 | alanya
# Procssing Record 479 of Set 1 | palmas
# Procssing Record 480 of Set 1 | broken hill
# Procssing Record 481 of Set 1 | vasilsursk
# Procssing Record 482 of Set 1 | tobol
# Procssing Record 483 of Set 1 | dunedin
# Procssing Record 484 of Set 1 | taoudenni
# Procssing Record 485 of Set 1 | karmana
# Procssing Record 486 of Set 1 | ust-nera
# Procssing Record 487 of Set 1 | okhotsk
# Procssing Record 488 of Set 1 | rossosh
# Procssing Record 489 of Set 1 | paldiski
# Procssing Record 490 of Set 1 | tete
# Procssing Record 491 of Set 1 | vallenar
# Procssing Record 492 of Set 1 | moskovskiy
# Procssing Record 493 of Set 1 | kouango
# Procssing Record 494 of Set 1 | kibala
# Procssing Record 495 of Set 1 | vikevag
# Procssing Record 496 of Set 1 | sant julia de loria
# Procssing Record 497 of Set 1 | saryshagan
# Procssing Record 498 of Set 1 | labuhan
# Procssing Record 499 of Set 1 | dolbeau
# Procssing Record 500 of Set 1 | avera
# Procssing Record 501 of Set 1 | auki
# Procssing Record 502 of Set 1 | malakal
# Procssing Record 503 of Set 1 | daru
# Procssing Record 504 of Set 1 | beitbridge
# Procssing Record 505 of Set 1 | mahon
# Procssing Record 506 of Set 1 | skibbereen
# Procssing Record 507 of Set 1 | sao luiz gonzaga
# Procssing Record 508 of Set 1 | inderborskiy
# Procssing Record 509 of Set 1 | nishihara
# Procssing Record 510 of Set 1 | alice springs
# Procssing Record 511 of Set 1 | nome
# Procssing Record 512 of Set 1 | kasempa
# Procssing Record 513 of Set 1 | neryungri
# Procssing Record 514 of Set 1 | bloemfontein
# Procssing Record 515 of Set 1 | aklavik
# Procssing Record 516 of Set 1 | plastun
# Procssing Record 517 of Set 1 | almaznyy
# Procssing Record 518 of Set 1 | elko
# Procssing Record 519 of Set 1 | villarrica
# Procssing Record 520 of Set 1 | aniva
# Procssing Record 521 of Set 1 | bahia de caraquez
# Procssing Record 522 of Set 1 | muheza
# Procssing Record 523 of Set 1 | cabo san lucas
# Procssing Record 524 of Set 1 | medford
# Procssing Record 525 of Set 1 | namibe
# Procssing Record 526 of Set 1 | katangli
# Procssing Record 527 of Set 1 | longlac
# Procssing Record 528 of Set 1 | washougal
# Procssing Record 529 of Set 1 | mutsamudu
# Procssing Record 530 of Set 1 | nova vicosa
# -----------------------------------
# Data Retrieval Complete
# -----------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict ={
    "City": city_name,
    "Country":country,
    "Date":date,
    "Humidity":humidity,
    "Lat":lat,
    "Lng":lng,
    "Max Temp": max_temp,
    "Wind Speed":wind_speed,
    "Cloudiness":cloudiness
}

# %%
weather_df = pd.DataFrame(weather_dict)
weather_df.head()
# Out:
#            City Country        Date  Humidity    Lat     Lng  Max Temp  \
# 0  Komsomolskiy      RU  1578277174        94  67.55   63.78    260.43
# 1       Qaanaaq      GL  1578277340        51  77.48  -69.36    241.34
# 2          Duku      ID  1578277555        55  -1.19  100.47    301.08
# 3  Kudahuvadhoo      MV  1578277555        78   2.67   72.89    301.20
# 4   Port Alfred      ZA  1578277555        93 -33.59   26.89    293.15
#
#    Wind Speed  Cloudiness
# 0        7.59         100
# 1        1.32          74
# 2        1.22           0
# 3        5.11         100
# 4        1.40          99

# %%
weather_df.count()
# Out:
# City          530
# Country       530
# Date          530
# Humidity      530
# Lat           530
# Lng           530
# Max Temp      530
# Wind Speed    530
# Cloudiness    530
# dtype: int64

# %%
# save the weather_df to 
weather_df.to_csv(output_data_file)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# converting max weather K to F 
weather_Max_f = (weather_df["Max Temp"]-273.15)*(9/5)+32
# Out:
# 0      67.55
# 1      77.48
# 2      -1.19
# 3       2.67
# 4     -33.59
#        ...
# 525   -43.15
# 526    -8.15
# 527    50.70
# 528    10.69
# 529    24.83
# Name: Lat, Length: 530, dtype: float64

# %%
plt.figure(figsize=(10,5))
plt.title('Latitude vs. Temperature Plot')
plt.scatter(weather_df['Lat'],weather_Max_f, marker = "o",alpha=0.5)
plt.xlabel("Latitude")
plt.ylabel("Temperature"+'(F)')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(10,5))
plt.title('Latitude vs. Humidity Plot')
plt.scatter(weather_df['Lat'],weather_df['Humidity'], marker = "o",alpha=.5, color="g")
plt.xlabel("Latitude")
plt.ylabel("Humidity"+'(%)')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(10,5))
plt.title('Latitude vs. Cloudiness Plot')
plt.scatter(weather_df['Lat'],weather_df['Cloudiness'], marker = "o", alpha=.5,color='purple')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness"+'(%)')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(10,5))
plt.title('Latitude vs. Wind Speed Plot')
plt.scatter(weather_df['Lat'],(weather_df['Wind Speed']*3), marker = "o",alpha=.5, color='brown')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed"+'(mph)')
plt.grid(True)
plt.show()

# %%
# 3 obsarvations:

# %%
#1

# %%
#2

# %%
#3
